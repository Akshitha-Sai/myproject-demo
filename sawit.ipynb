# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha-Sai/myproject-demo/blob/main/sawit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Create a more comprehensive dataset
data = {
    "English": [
        "How are you?", "What's up?", "Where are you?", "Come here!",
        "Let's go!", "I'm hungry", "How much is this?", "I don't know",
        "What are you doing?", "Did you eat?", "Don't worry",
        "What's your name?", "I'm fine", "Where are you from?", "What time is it?",
        "How can I help you?", "Take care!", "See you later", "Can you help me?",
        "I'm sorry", "It's okay", "Let's eat", "It's raining", "I will come",
        "Do you understand?", "Wait for me", "I'm busy", "Please wait",
        "I love reading books", "She is an amazing friend",
        "The weather is nice today", "My favorite color is blue",
        "I enjoy playing sports", "He works as a doctor", "This place is beautiful",
        "She loves cooking", "The sun is shining brightly", "He likes to travel",
        "This is my new car", "The garden looks lovely",
        "She sings very well", "He is very kind", "I am learning a new language",
        "This movie is interesting", "She is wearing a red dress",
        "I like to swim", "The cake tastes delicious", "He plays the guitar",
        "This city is very big", "She is very intelligent", "I like to draw"
    ],
    "Telugu": [
        "ఎలా ఉన్నావు?", "ఏమిటి మచ్చి?", "ఎక్కడ ఉన్నావు?", "ఇక్కడ రా!",
        "పోదాం!", "హంగ్రీ గాను ఉన్నాను", "ఇది ఎంత?", "నేను తెలియదు",
        "ఏం చేస్తున్నావు?", "తినారా?", "చింతించకూ",
        "నీ పేరు ఏమిటి?", "నేను బాగున్నాను", "నీవు ఎక్కడ నుండి?", "సమయం ఎం?" ,
        "నేను ఎలా సహాయం చేయగలను?", "జాగ్రత్తగా ఉండి!", "మళ్లీ కలుద్దాం", "నేను సహాయం చేయగలనా?",
        "క్షమించు", "సరే", "వెళ్ళి తినుకుందాం", "వర్షం పడుతోంది", "నేను రాగలును",
        "నీకు అర్థమయ్యింది?", "నన్ను వేచి ఉండి", "నేను బిజీగా ఉన్నాను", "దయచేసి ఆగండి",
        "నాకు పుస్తకాలు చదవడం ఇష్టం", "ఆమె అద్భుతమైన స్నేహితురాలు",
        "ఈ రోజు వాతావరణం మంచి ఉంది", "నా ఇష్టమైన రంగు నీలం",
        "నాకు క్రీడలు ఆడటం ఇష్టం", "అతను ఒక వైద్యుడు", "ఈ స్థలం అందంగా ఉంది",
        "ఆమె వంట చేసుకోవడం ఇష్టం", "సూర్యుడు ప్రకాశిస్తున్నాడు", "అతనికి ప్రయాణాలు చేయడం ఇష్టం",
        "ఇది నా కొత్త కారు", "తోట అందంగా ఉంది",
        "ఆమె చాలా బాగా పాడుతుంది", "అతను చాలా దయతో ఉంటాడు", "నేను ఒక కొత్త భాష నేర్చుకుంటున్నాను",
        "ఈ సినిమా ఆసక్తికరంగా ఉంది", "ఆమె ఎరుపు బట్టలు ధరించింది",
        "నాకు ఈత ఇష్టం", "కేక్ రుచి బాగుంది", "అతను గిటార్ వాయిస్తాడు",
        "ఈ నగరం చాలా పెద్దది", "ఆమె చాలా తెలివిగా ఉంటుంది", "నాకు గీయడం ఇష్టం"
    ]
}

# Convert to a DataFrame
df = pd.DataFrame(data)

# Save as CSV file
df.to_csv("telugu_dataset.csv", index=False)

# Show the dataset
df
# Out:
#                          English                               Telugu
# 0                   How are you?                         ఎలా ఉన్నావు?
# 1                     What's up?                         ఏమిటి మచ్చి?
# 2                 Where are you?                       ఎక్కడ ఉన్నావు?
# 3                     Come here!                            ఇక్కడ రా!
# 4                      Let's go!                               పోదాం!
# 5                     I'm hungry                  హంగ్రీ గాను ఉన్నాను
# 6              How much is this?                             ఇది ఎంత?
# 7                   I don't know                         నేను తెలియదు
# 8            What are you doing?                     ఏం చేస్తున్నావు?
# 9                   Did you eat?                              తినారా?
# 10                   Don't worry                            చింతించకూ
# 11             What's your name?                       నీ పేరు ఏమిటి?
# ...

# %%
# !pip install transformers datasets torch

# %%
import pandas as pd

# Create a DataFrame with expanded dataset
df = pd.DataFrame(data)

# Save the expanded dataset properly
df.to_csv("telugu_dataset.csv", index=False, encoding="utf-8")

# Verify the dataset was saved correctly
print("Dataset saved successfully with", len(df), "rows.")
# Out:
# Dataset saved successfully with 51 rows.

# %%
# Load the dataset again
df_loaded = pd.read_csv("telugu_dataset.csv", encoding="utf-8")

# Display dataset size and first few rows
print("Loaded dataset has", len(df_loaded), "rows.")
print(df_loaded.head(10))  # Show the first 10 rows
# Out:
# Loaded dataset has 51 rows.
#                English               Telugu
# 0         How are you?         ఎలా ఉన్నావు?
# 1           What's up?         ఏమిటి మచ్చి?
# 2       Where are you?       ఎక్కడ ఉన్నావు?
# 3           Come here!            ఇక్కడ రా!
# 4            Let's go!               పోదాం!
# 5           I'm hungry  హంగ్రీ గాను ఉన్నాను
# 6    How much is this?             ఇది ఎంత?
# 7         I don't know         నేను తెలియదు
# 8  What are you doing?     ఏం చేస్తున్నావు?
# 9         Did you eat?              తినారా?

# %%
# !pip install transformers datasets torch sentencepiece

# %%
import pandas as pd
from datasets import Dataset

# Load the dataset
df = pd.read_csv("telugu_dataset.csv")

# Convert DataFrame to Hugging Face Dataset format
dataset = Dataset.from_pandas(df)

# Check the dataset structure
print(dataset)
# Out:
# Dataset({
#     features: ['English', 'Telugu'],
#     num_rows: 51
# })

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast

# Load tokenizer and model
model_name = "facebook/mbart-large-50-many-to-many-mmt"
tokenizer = MBart50TokenizerFast.from_pretrained(model_name, src_lang="en_XX", tgt_lang="te_IN")
model = MBartForConditionalGeneration.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/529 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/649 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]

# %%
def preprocess_data(example):
    inputs = tokenizer(example["English"], max_length=50, padding="max_length", truncation=True, return_tensors="pt")
    targets = tokenizer(example["Telugu"], max_length=50, padding="max_length", truncation=True, return_tensors="pt")
    return {
        "input_ids": inputs["input_ids"].squeeze(),
        "attention_mask": inputs["attention_mask"].squeeze(),
        "labels": targets["input_ids"].squeeze()
    }

# Apply preprocessing
tokenized_dataset = dataset.map(preprocess_data, remove_columns=["English", "Telugu"])
# Out:
# Map:   0%|          | 0/51 [00:00<?, ? examples/s]

# %%
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.01,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
)

# Start training
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-feb90265ecfe> in <cell line: 0>()
#      11 )
#      12
# ---> 13 trainer = Trainer(
#      14     model=model,
#      15     args=training_args,
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/deprecation.py in wrapped_func(*args, **kwargs)
#     163                 warnings.warn(message, FutureWarning, stacklevel=2)
#     164
# --> 165             return func(*args, **kwargs)
#     166
#     167         return wrapped_func
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer.py in __init__(self, model, args, data_collator, train_dataset, eval_dataset, processing_class, model_init, compute_loss_func, compute_metrics, callbacks, optimizers, optimizer_cls_and_kwargs, preprocess_logits_for_metrics)
#     439                 )
# ...

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
from datasets import load_dataset

# Load dataset from CSV file
dataset = load_dataset("csv", data_files="telugu_dataset.csv")

# Convert to Pandas DataFrame
df = dataset["train"].to_pandas()

# Check if the dataset is loaded correctly
print(df.head())  # Print first 5 rows to verify
# Out:
#           English          Telugu
# 0    How are you?    ఎలా ఉన్నావు?
# 1      What's up?    ఏమిటి మచ్చి?
# 2  Where are you?  ఎక్కడ ఉన్నావు?
# 3      Come here!       ఇక్కడ రా!
# 4       Let's go!          పోదాం!

# %%
import pandas as pd

# Load dataset using pandas
df = pd.read_csv("telugu_dataset.csv")

# Check if all rows are loaded
print(f"Total rows: {len(df)}")  # Should print 51
print(df.head())  # Display first 5 rows
# Out:
# Total rows: 51
#           English          Telugu
# 0    How are you?    ఎలా ఉన్నావు?
# 1      What's up?    ఏమిటి మచ్చి?
# 2  Where are you?  ఎక్కడ ఉన్నావు?
# 3      Come here!       ఇక్కడ రా!
# 4       Let's go!          పోదాం!

# %%
from datasets import Dataset

# Convert Pandas DataFrame to Hugging Face Dataset
dataset = Dataset.from_pandas(df)

# Verify dataset length
print(dataset)
# Out:
# Dataset({
#     features: ['English', 'Telugu'],
#     num_rows: 51
# })

# %%
from transformers import AutoTokenizer

# Load tokenizer (change model_name based on your choice)
model_name = "google/mt5-small"
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# ...

# %%
def preprocess_data(examples):
    inputs = tokenizer(examples["English"], padding="max_length", truncation=True, max_length=128)
    targets = tokenizer(examples["Telugu"], padding="max_length", truncation=True, max_length=128)
    inputs["labels"] = targets["input_ids"]
    return inputs

# %%
# Tokenize the dataset
tokenized_dataset = dataset.map(preprocess_data, remove_columns=["English", "Telugu"])

# Split into train and eval sets
from sklearn.model_selection import train_test_split
from datasets import Dataset

df_train, df_eval = train_test_split(df, test_size=0.1, random_state=42)

train_dataset = Dataset.from_pandas(df_train)
eval_dataset = Dataset.from_pandas(df_eval)

tokenized_train = train_dataset.map(preprocess_data, remove_columns=["English", "Telugu"])
tokenized_eval = eval_dataset.map(preprocess_data, remove_columns=["English", "Telugu"])
# Out:
# ...
# Map:   0%|          | 0/6 [00:00<?, ? examples/s]

# %%
from transformers import TrainingArguments, Trainer, AutoModelForSeq2SeqLM

# Load model
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=3,
    weight_decay=0.01,
    report_to="none"  # Prevents API key issues with W&B
)

# Define Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_eval,
)

# Start training
trainer.train()
# Out:
# pytorch_model.bin:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
#     <div>
#
#       <progress value='36' max='36' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [36/36 20:18, Epoch 2.92/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
# ...

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='4' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 01:04]
#     </div>
# {'eval_loss': 60.39796829223633,
#  'eval_runtime': 11.8006,
#  'eval_samples_per_second': 0.508,
#  'eval_steps_per_second': 0.169,
#  'epoch': 3.0}

# %%
model.save_pretrained("telugu_translation_model")
tokenizer.save_pretrained("telugu_translation_model")
# Out:
# ('telugu_translation_model/tokenizer_config.json',
#  'telugu_translation_model/special_tokens_map.json',
#  'telugu_translation_model/spiece.model',
#  'telugu_translation_model/added_tokens.json',
#  'telugu_translation_model/tokenizer.json')

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

model = AutoModelForSeq2SeqLM.from_pretrained("telugu_translation_model")
tokenizer = AutoTokenizer.from_pretrained("telugu_translation_model")

# %%
def translate_text(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=128)
    outputs = model.generate(**inputs)
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return translated_text

# Example
english_text = "Hello, how are you?"
telugu_translation = translate_text(english_text)
print("Telugu Translation:", telugu_translation)
# Out:
# Telugu Translation: <extra_id_0>

# %%
model.save_pretrained("telugu_translation_model")
tokenizer.save_pretrained("telugu_translation_model")
# Out:
# ('telugu_translation_model/tokenizer_config.json',
#  'telugu_translation_model/special_tokens_map.json',
#  'telugu_translation_model/spiece.model',
#  'telugu_translation_model/added_tokens.json',
#  'telugu_translation_model/tokenizer.json')

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

model = AutoModelForSeq2SeqLM.from_pretrained("telugu_translation_model")
tokenizer = AutoTokenizer.from_pretrained("telugu_translation_model")

# %%
def translate_text(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=128)
    outputs = model.generate(**inputs)
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return translated_text

# Example Usage
english_text = "I love reading books."
telugu_translation = translate_text(english_text)
print("Telugu Translation:", telugu_translation)
# Out:
# Telugu Translation: <extra_id_0>

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
model.save_pretrained("telugu_translation_model")
tokenizer.save_pretrained("telugu_translation_model")
# Out:
# ('telugu_translation_model/tokenizer_config.json',
#  'telugu_translation_model/special_tokens_map.json',
#  'telugu_translation_model/spiece.model',
#  'telugu_translation_model/added_tokens.json',
#  'telugu_translation_model/tokenizer.json')

# %%
from huggingface_hub import whoami

print(whoami())
# Out:
# {'type': 'user', 'id': '67b724be299e4d30f9ef7441', 'name': 'AkshithaSai19', 'fullname': 'Babbili Akshitha Sai', 'email': 'akshithasai19@gmail.com', 'emailVerified': True, 'canPay': False, 'periodEnd': None, 'isPro': False, 'avatarUrl': '/avatars/ec16a622d636077038d46314c343bc23.svg', 'orgs': [], 'auth': {'type': 'access_token', 'accessToken': {'displayName': 'sawit_token', 'role': 'write', 'createdAt': '2025-02-20T13:11:26.783Z'}}}

# %%
from huggingface_hub import create_repo

# Replace with your Hugging Face username
username = "AkshithaSai19"
repo_name = "telugu_translation_model"

# Try creating the repo again
create_repo(f"{username}/{repo_name}", exist_ok=True)
# Out:
# RepoUrl('https://huggingface.co/AkshithaSai19/telugu_translation_model', endpoint='https://huggingface.co', repo_type='model', repo_id='AkshithaSai19/telugu_translation_model')

# %%
from huggingface_hub import upload_folder

upload_folder(folder_path="telugu_translation_model", repo_id=f"{username}/{repo_name}")
# Out:
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# Upload 3 LFS files:   0%|          | 0/3 [00:00<?, ?it/s]
# CommitInfo(commit_url='https://huggingface.co/AkshithaSai19/telugu_translation_model/commit/273201397b600a6b0bba66891905df783f734638', commit_message='Upload folder using huggingface_hub', commit_description='', oid='273201397b600a6b0bba66891905df783f734638', pr_url=None, repo_url=RepoUrl('https://huggingface.co/AkshithaSai19/telugu_translation_model', endpoint='https://huggingface.co', repo_type='model', repo_id='AkshithaSai19/telugu_translation_model'), pr_revision=None, pr_num=None)

# %%
# !pip install transformers torch sentencepiece

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

# Define model repo ID
repo_id = "AkshithaSai19/telugu_translation_model"

# Load the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(repo_id)
model = AutoModelForSeq2SeqLM.from_pretrained(repo_id)

print("Model and tokenizer loaded successfully!")
# Out:
# tokenizer_config.json:   0%|          | 0.00/19.5k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/416 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/810 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# Model and tokenizer loaded successfully!

# %%
def translate_text(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)
    outputs = model.generate(**inputs)
    translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return translated_text

# Example translation
english_text = "Hello, how are you?"
telugu_translation = translate_text(english_text)

print("Telugu Translation:", telugu_translation)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Telugu Translation: <extra_id_0>

# %%
# !pip install gradio

import gradio as gr

def translate_interface(text):
    return translate_text(text)

# Create Gradio app
demo = gr.Interface(fn=translate_interface, inputs="text", outputs="text")
demo.launch()
# Out:
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/safehttpx/
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 10.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 52.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
# ...
